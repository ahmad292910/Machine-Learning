# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmad292910/Machine-Learning/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/data.csv')

# %%
df.head()
# Out:
#    id  color  value
# 0   1    red   10.5
# 1   2   blue    8.2
# 2   3  green    5.1
# 3   4    red    7.8
# 4   5   blue    9.3

# %%
df.tail()
# Out:
#    id  color  value
# 0   1    red   10.5
# 1   2   blue    8.2
# 2   3  green    5.1
# 3   4    red    7.8
# 4   5   blue    9.3

# %%
df.sample(2)
# Out:
#    id  color  value
# 2   3  green    5.1
# 3   4    red    7.8

# %%
df.shape
# Out:
# (5, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      5 non-null      int64
#  1   color   5 non-null      object
#  2   value   5 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 248.0+ bytes

# %%
df.describe()
# Out:
#              id     value
# count  5.000000   5.00000
# mean   3.000000   8.18000
# std    1.581139   2.01668
# min    1.000000   5.10000
# 25%    2.000000   7.80000
# 50%    3.000000   8.20000
# 75%    4.000000   9.30000
# max    5.000000  10.50000

# %%
df.iloc[:,1:]   #slicing
# Out:
#    color  value
# 0    red   10.5
# 1   blue    8.2
# 2  green    5.1
# 3    red    7.8
# 4   blue    9.3

# %%
df.value_counts()
# Out:
# id  color  value
# 1   red    10.5     1
# 2   blue   8.2      1
# 3   green  5.1      1
# 4   red    7.8      1
# 5   blue   9.3      1
# dtype: int64

# %%
df.drop_duplicates(subset=['color'],inplace=True)

# %%
df.corr()
# Out:
# <ipython-input-21-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              id     value
# id     1.000000 -0.996362
# value -0.996362  1.000000

# %%
df.rename(columns={'color':'colour'},inplace=True)

# %%
df
# Out:
#    id colour  value
# 0   1    red   10.5
# 1   2   blue    8.2
# 2   3  green    5.1

# %%
df.dropna()
# Out:
#    id colour  value
# 0   1    red   10.5
# 1   2   blue    8.2
# 2   3  green    5.1

# %%
df.fillna(method='ffill')
# Out:
#    id colour  value
# 0   1    red   10.5
# 1   2   blue    8.2
# 2   3  green    5.1

# %%
df.fillna(method='bfill')
# Out:
#    id colour  value
# 0   1    red   10.5
# 1   2   blue    8.2
# 2   3  green    5.1
